# %% [markdown]
# # Variables

# %%
a = 123

# %%
a
# Out:
# 123

# %%
print(a)
# Out:
# 123

# %%
type(a)
# Out:
# int

# %%
b = 0.45

# %%
type(b)
# Out:
# float

# %%
a = 123
b = 45

# %%
a, b
# Out:
# (123, 45)

# %%
print(a,b)
# Out:
# 123 45

# %%
a + b
# Out:
# 168

# %%
a + b, a - b, a * b, a / b
# Out:
# (168, 78, 5535, 2.7333333333333334)

# %%
a // b
# Out:
# 2

# %%
a % b
# Out:
# 33

# %%
b
# Out:
# 45

# %%
b ** 2
# Out:
# 2025

# %%
b ** 10
# Out:
# 34050628916015625

# %%
c = 'Hello'

# %%
c
# Out:
# 'Hello'

# %%
d = 'world!'

# %%
d
# Out:
# 'world!'

# %%
type(c)
# Out:
# str

# %%
type(d)
# Out:
# str

# %%
a
b
c
d
# Out:
# 'world!'

# %%
print(a)
print(b)
print(c)
print(d)
# Out:
# 123
# 45
# Hello
# world!

# %%
a, b, c, d
# Out:
# (123, 45, 'Hello', 'world!')

# %%
print(a, b, c, d)
# Out:
# 123 45 Hello world!

# %%
print(a + b)
# Out:
# 168

# %%
print(c + d)
# Out:
# Helloworld!

# %% [markdown]
# # List

# %%
a = [10, 20, 30, 40, 50]

# %%
a
# Out:
# [10, 20, 30, 40, 50]

# %%
print(a)
# Out:
# [10, 20, 30, 40, 50]

# %%
type(a)
# Out:
# list

# %%
sum(a)
# Out:
# 150

# %%
len(a)
# Out:
# 5

# %%
max(a)
# Out:
# 50

# %%
min(a)
# Out:
# 10

# %%
a[0]
# Out:
# 10

# %%
a[1]
# Out:
# 20

# %%
a[4]
# Out:
# 50

# %%
a[-1]
# Out:
# 50

# %%
a[-5]
# Out:
# 10

# %%
a[1:3]
# Out:
# [20, 30]

# %%
a[1:]
# Out:
# [20, 30, 40, 50]

# %%
a[:3]
# Out:
# [10, 20, 30]

# %%
sum(a[:3])
# Out:
# 60

# %%
max(a[:3])
# Out:
# 30

# %%
b = [100, 200, 300]

# %%
a
# Out:
# [10, 20, 30, 40, 50]

# %%
b
# Out:
# [100, 200, 300]

# %%
a + b
# Out:
# [10, 20, 30, 40, 50, 100, 200, 300]

# %%
c = a + b

# %%
c
# Out:
# [10, 20, 30, 40, 50, 100, 200, 300]

# %%
type(c)
# Out:
# list

# %%
c.append(99)

# %%
c
# Out:
# [10, 20, 30, 40, 50, 100, 200, 300, 99]

# %%
del c[1]

# %%
c
# Out:
# [10, 30, 40, 50, 100, 200, 300, 99]

# %%
c.remove(200)

# %%
c
# Out:
# [10, 30, 40, 50, 100, 300, 99]

# %%
d = [10, 20, [30, 40, 50, 60]]

# %%
d
# Out:
# [10, 20, [30, 40, 50, 60]]

# %%
len(d)
# Out:
# 3

# %%
d[2]
# Out:
# [30, 40, 50, 60]

# %%
len(d[2])
# Out:
# 4

# %%
sum(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-3b8b3f92adcf> in <module>()
# ----> 1 sum(d)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
sum(d[:2])
# Out:
# 30

# %%
sum(d[2])
# Out:
# 180

# %% [markdown]
# # Tuple

# %%
a = [10, 20, 30, 40, 50]

# %%
b = (10, 20, 30, 40, 50)

# %%
type(a)
# Out:
# list

# %%
type(b)
# Out:
# tuple

# %%
a[0] = 100

# %%
a
# Out:
# [100, 20, 30, 40, 50]

# %%
b[0 = 100]
# Out:
#   File "<ipython-input-95-9698bf297b11>", line 1
#     b[0 = 100]
#         ^
# SyntaxError: invalid syntax

# %%
del b[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-0cde02571307> in <module>()
# ----> 1 del b[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
sum(b)
# Out:
# 150

# %%
len(b)
# Out:
# 5

# %%
max(b)
# Out:
# 50

# %%
min(b)
# Out:
# 10

# %%
b[0]
# Out:
# 10

# %%
b[4]
# Out:
# 50

# %%
b[-1]
# Out:
# 50

# %%
b[-5]
# Out:
# 10

# %%
b[1:3]
# Out:
# (20, 30)

# %%
b[1:]
# Out:
# (20, 30, 40, 50)

# %%
a[1:]
# Out:
# [20, 30, 40, 50]

# %%
b[:3]
# Out:
# (10, 20, 30)

# %%
sum(b[:3])
# Out:
# 60

# %%
c = (100, 200, 300)

# %%
b + c
# Out:
# (10, 20, 30, 40, 50, 100, 200, 300)

# %%
d = b + c

# %%
type(d)
# Out:
# tuple

# %%
d
# Out:
# (10, 20, 30, 40, 50, 100, 200, 300)

# %%
e = ((10, 20), [30, 40, 50])

# %%
e
# Out:
# ((10, 20), [30, 40, 50])

# %%
type(e)
# Out:
# tuple

# %%
len(e)
# Out:
# 2

# %%
e[0]
# Out:
# (10, 20)

# %%
e[1]
# Out:
# [30, 40, 50]

# %%
type(e[0])
# Out:
# tuple

# %%
type(e[1])
# Out:
# list

# %%
len(e[0])
# Out:
# 2

# %%
len(e[1])
# Out:
# 3

# %%
sum(e[0])
# Out:
# 30

# %%
sum(e[1])
# Out:
# 120
